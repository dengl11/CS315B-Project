# %%
""" Style """
import warnings
warnings.filterwarnings("ignore")  # suppres all warnings

""" Autoload """
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # My Decision Tree

# %%
""" Backend """
from iris_myclassification import *

# %%
print(my_tree)
# Out:
#  Depth 0 -> Split by Feature 2 at 4.8  (Gini = 0.50) | # Nodes: 75
# 	 Depth 1 -> Split by Feature 3 at 1.6  (Gini = 0.14) | # Nodes: 39
# 		 Depth 2 -> [0] (Gini = 0.00) | # Nodes: 35
# 		 Depth 2 -> Split by Feature 1 at 3.0  (Gini = 0.38) | # Nodes: 4
# 			 Depth 3 -> [1] (Gini = 0.00) | # Nodes: 3
# 			 Depth 3 -> [0] (Gini = 0.00) | # Nodes: 1
# 	 Depth 1 -> Split by Feature 2 at 5.0  (Gini = 0.05) | # Nodes: 36
# 		 Depth 2 -> Split by Feature 0 at 6.3  (Gini = 0.32) | # Nodes: 5
# 			 Depth 3 -> [1] (Gini = 0.00) | # Nodes: 4
# 			 Depth 3 -> [0] (Gini = 0.00) | # Nodes: 1
# 		 Depth 2 -> [1] (Gini = 0.00) | # Nodes: 31

# %% [markdown]
# # Sklearn Decision Tree

# %%
""" sklearn """
import graphviz 
from sklearn import tree
from iris_sklearn_classification import *
dot_data = tree.export_graphviz(estimator, out_file=None)
graph = graphviz.Source(dot_data) 
graph
# Out:
# ------------------- Sklearn Decision Tree -------------------
# Train Accuracy: 0.99
# Test Accuracy : 0.88
