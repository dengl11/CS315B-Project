# %%
""" Style """
import warnings
warnings.filterwarnings("ignore")  # suppres all warnings

""" Autoload """
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # My Decision Tree

# %%
""" Backend """
from my_classification import *
# Out:
# ------------------- My Decision Tree -------------------
# Train Accuracy: 0.98
# Test Accuracy : 0.92

# %%
print(my_tree)
# Out:
#  Depth 0 -> Split by Feature 7 at 0.04846  (Gini = 0.47) | # Nodes: 426
# 	 Depth 1 -> Split by Feature 20 at 17.38  (Gini = 0.09) | # Nodes: 260
# 		 Depth 2 -> Split by Feature 13 at 41.24  (Gini = 0.05) | # Nodes: 252
# 			 Depth 3 -> [1] (Gini = 0.03) | # Nodes: 247
# 			 Depth 3 -> [0] (Gini = 0.48) | # Nodes: 5
# 		 Depth 2 -> Split by Feature 1 at 18.29  (Gini = 0.38) | # Nodes: 8
# 			 Depth 3 -> [1] (Gini = 0.00) | # Nodes: 2
# 			 Depth 3 -> [0] (Gini = 0.00) | # Nodes: 6
# 	 Depth 1 -> Split by Feature 23 at 783.6  (Gini = 0.21) | # Nodes: 166
# 		 Depth 2 -> Split by Feature 21 at 23.73  (Gini = 0.49) | # Nodes: 30
# 			 Depth 3 -> [1] (Gini = 0.00) | # Nodes: 14
# 			 Depth 3 -> [0] (Gini = 0.30) | # Nodes: 16
# 		 Depth 2 -> Split by Feature 10 at 0.1745  (Gini = 0.04) | # Nodes: 136
# 			 Depth 3 -> [1] (Gini = 0.00) | # Nodes: 2
# 			 Depth 3 -> [0] (Gini = 0.01) | # Nodes: 134

# %% [markdown]
# # Sklearn Decision Tree

# %%
""" sklearn """
import graphviz 
from sklearn import tree
from sklearn_classification import *
dot_data = tree.export_graphviz(estimator, out_file=None)
graph = graphviz.Source(dot_data) 
graph
# Out:
# ------------------- Sklearn Decision Tree -------------------
# Train Accuracy: 0.98
# Test Accuracy : 0.94
